# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import datetime
from decimal import *
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
data_path = "California_Fire_Incidents.csv"

# %%
fire_data = pd.read_csv(data_path)
fire_data
# Out:
#       AcresBurned  Active                                          AdminUnit  \
# 0        257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1         30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2         27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3         27440.0   False                              Tahoe National Forest
# 4         24251.0   False                       Ventura County Fire/CAL FIRE
# ...           ...     ...                                                ...
# 1631          9.0   False                   CAL FIRE / Riverside County Fire
# 1632          2.0   False                  CAL FIRE Nevada-Yuba-Placer Unit
# 1633          NaN   False               Yolo County Fire Protection District
# 1634          NaN   False                   Camp Pendleton Marine Corps Base
# 1635          NaN   False                           Bureau of Indian Affairs
#
#       AirTankers  ArchiveYear  CalFireIncident  \
# 0            NaN         2013             True
# 1            NaN         2013             True
# 2            NaN         2013             True
# 3            NaN         2013            False
# 4            NaN         2013             True
# ...          ...          ...              ...
# 1631         NaN         2019             True
# 1632         NaN         2019             True
# 1633         NaN         2019            False
# 1634         NaN         2019            False
# 1635         NaN         2019            False
#
#                                CanonicalUrl  \
# 0            /incidents/2013/8/17/rim-fire/
# 1     /incidents/2013/5/30/powerhouse-fire/
# 2       /incidents/2013/7/15/mountain-fire/
# 3       /incidents/2013/8/10/american-fire/
# 4         /incidents/2013/5/2/springs-fire/
# ...                                     ...
# 1631      /incidents/2019/10/10/eagle-fire/
# 1632        /incidents/2019/6/28/long-fire/
# 1633      /incidents/2019/11/25/cashe-fire/
# 1634        /incidents/2019/10/22/oak-fire/
# 1635    /incidents/2019/10/14/johnson-fire/
#
#                                      ConditionStatement ControlStatement  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4     Acreage has been reduced based upon more accur...              NaN
# ...                                                 ...              ...
# 1631                                                NaN              NaN
# 1632                                                NaN              NaN
# 1633                                                NaN              NaN
# 1634                                                NaN              NaN
# 1635  As of 10:00 p.m. on 10/16, the fire is 90% con...              NaN
#
#          Counties  ...                                     SearchKeywords  \
# 0        Tuolumne  ...  Rim Fire, Stanislaus National Forest, Yosemite...
# 1     Los Angeles  ...  Powerhouse Fire, May 2013, June 2013, Angeles ...
# 2       Riverside  ...  Mountain Fire, July 2013, Highway 243, Highway...
# 3          Placer  ...  American Fire, August 2013, Deadwood Ridge, Fo...
# 4         Ventura  ...  Springs Fire, May 2013, Highway 101, Camarillo...
# ...           ...  ...                                                ...
# 1631    Riverside  ...                                                NaN
# 1632       Nevada  ...                                                NaN
# 1633         Yolo  ...                                                NaN
# 1634    San Diego  ...                                                NaN
# 1635    Riverside  ...                                                NaN
#
#                    Started     Status  StructuresDamaged StructuresDestroyed  \
# 0     2013-08-17T15:25:00Z  Finalized                NaN                 NaN
# 1     2013-05-30T15:28:00Z  Finalized                NaN                 NaN
# 2     2013-07-15T13:43:00Z  Finalized                NaN                 NaN
# 3     2013-08-10T16:30:00Z  Finalized                NaN                 NaN
# 4     2013-05-02T07:01:00Z  Finalized                6.0                10.0
# ...                    ...        ...                ...                 ...
# 1631  2019-10-10T12:08:00Z  Finalized                NaN                 NaN
# 1632  2019-06-28T15:03:04Z  Finalized                NaN                 NaN
# 1633  2019-11-25T12:02:02Z  Finalized                NaN                 NaN
# 1634  2019-10-22T19:20:44Z  Finalized                NaN                 NaN
# 1635  2019-10-14T15:32:20Z   Inactive                NaN                 NaN
#
#       StructuresEvacuated  StructuresThreatened  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ...                   ...                   ...
# 1631                  NaN                   NaN
# 1632                  NaN                   NaN
# 1633                  NaN                   NaN
# 1634                  NaN                   NaN
# 1635                  NaN                   NaN
#
#                                   UniqueId                   Updated  \
# 0     5fb18d4d-213f-4d83-a179-daaf11939e78      2013-09-06T18:30:00Z
# 1     bf37805e-1cc2-4208-9972-753e47874c87      2013-06-08T18:30:00Z
# 2     a3149fec-4d48-427c-8b2c-59e8b79d59db      2013-07-30T18:00:00Z
# 3     8213f5c7-34fa-403b-a4bc-da2ace6e6625      2013-08-30T08:00:00Z
# 4     46731fb8-3350-4920-bdf7-910ac0eb715c      2013-05-11T06:30:00Z
# ...                                    ...                       ...
# 1631  6e93b252-99a3-4214-9921-238373b17535  2019-10-10T18:11:59.733Z
# 1632  b38c0563-b321-431b-9174-6336c5a0d449  2019-06-30T15:52:01.023Z
# 1633  9c26f915-1b33-422d-b30a-9eb4da6fd729   2019-12-03T16:35:20.93Z
# 1634  7264a106-e0f4-41de-8fd0-3f9110431e28   2019-11-21T12:21:28.58Z
# 1635  8bf75401-999f-42bd-8c0a-8db508591545   2019-10-30T10:14:19.58Z
#
#       WaterTenders
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4             11.0
# ...            ...
# 1631           NaN
# 1632           NaN
# 1633           NaN
# 1634           NaN
# 1635           NaN
#
# [1636 rows x 40 columns]

# %%
correlation = st.pearsonr(bitcoin_price,dogecoin_price)
print(f"The correlation between both factors is {round(correlation[0],2)}")

# %%
correlation = fire_data.corr()
ax = sns.heatmap(correlation)
ax
# Out:
# <AxesSubplot:>

# %%
correlation
# Out:
#                       AcresBurned  Active  AirTankers  ArchiveYear  \
# AcresBurned              1.000000     NaN    0.087599     0.021717
# Active                        NaN     NaN         NaN          NaN
# AirTankers               0.087599     NaN    1.000000    -0.422612
# ArchiveYear              0.021717     NaN   -0.422612     1.000000
# CalFireIncident          0.000312     NaN    0.114180    -0.037969
# CrewsInvolved            0.090928     NaN    0.602916    -0.171530
# Dozers                   0.482626     NaN    0.779673     0.025457
# Engines                  0.226785     NaN    0.430673     0.006192
# Fatalities              -0.085491     NaN         NaN     0.007974
# Featured                -0.020167     NaN   -0.063433     0.164720
# Final                    0.003999     NaN         NaN    -0.035866
# Helicopters              0.126563     NaN    0.824106    -0.284903
# Injuries                -0.043369     NaN    0.799003    -0.326796
# Latitude                -0.002146     NaN   -0.018584     0.013854
# Longitude               -0.019493     NaN   -0.022760    -0.302928
# MajorIncident            0.174751     NaN    0.135550    -0.134723
# PercentContained              NaN     NaN         NaN          NaN
# PersonnelInvolved        0.258150     NaN    0.434371    -0.040967
# Public                        NaN     NaN         NaN          NaN
# StructuresDamaged        0.380060     NaN    0.887242     0.139441
# StructuresDestroyed      0.218043     NaN    0.572404     0.098759
# StructuresEvacuated           NaN     NaN         NaN          NaN
# StructuresThreatened     0.281418     NaN   -0.076033     0.086050
# WaterTenders             0.359249     NaN    0.802913    -0.031210
#
#                       CalFireIncident  CrewsInvolved    Dozers   Engines  \
# AcresBurned                  0.000312       0.090928  0.482626  0.226785
# Active                            NaN            NaN       NaN       NaN
# AirTankers                   0.114180       0.602916  0.779673  0.430673
# ArchiveYear                 -0.037969      -0.171530  0.025457  0.006192
# CalFireIncident              1.000000      -0.023443  0.017464 -0.109800
# CrewsInvolved               -0.023443       1.000000  0.653851  0.768906
# Dozers                       0.017464       0.653851  1.000000  0.768113
# Engines                     -0.109800       0.768906  0.768113  1.000000
# Fatalities                   0.094214       0.692500 -0.571689  0.994830
# Featured                     0.058976      -0.048471 -0.051396 -0.030575
# Final                        0.021828            NaN       NaN       NaN
# Helicopters                  0.064920       0.712983  0.741137  0.564906
# Injuries                    -0.091534       0.482640  0.130687  0.652636
# Latitude                     0.021362      -0.020862  0.116679  0.015031
# Longitude                   -0.085456      -0.007138 -0.113668 -0.042527
# MajorIncident                0.252262       0.054347  0.086416  0.056066
# PercentContained                  NaN            NaN       NaN       NaN
# PersonnelInvolved           -0.029175       0.823207  0.753657  0.943634
# Public                            NaN            NaN       NaN       NaN
# StructuresDamaged            0.029366      -0.158452  0.481004 -0.068927
# StructuresDestroyed          0.033550      -0.029503 -0.021198  0.066371
# StructuresEvacuated               NaN            NaN       NaN       NaN
# StructuresThreatened         0.151947       0.644368  0.593005  0.634078
# WaterTenders                -0.002747       0.736698  0.961062  0.832994
#
#                       Fatalities  Featured  ...  Longitude  MajorIncident  \
# AcresBurned            -0.085491 -0.020167  ...  -0.019493       0.174751
# Active                       NaN       NaN  ...        NaN            NaN
# AirTankers                   NaN -0.063433  ...  -0.022760       0.135550
# ArchiveYear             0.007974  0.164720  ...  -0.302928      -0.134723
# CalFireIncident         0.094214  0.058976  ...  -0.085456       0.252262
# CrewsInvolved           0.692500 -0.048471  ...  -0.007138       0.054347
# Dozers                 -0.571689 -0.051396  ...  -0.113668       0.086416
# Engines                 0.994830 -0.030575  ...  -0.042527       0.056066
# Fatalities              1.000000 -0.081848  ...  -0.036689            NaN
# Featured               -0.081848  1.000000  ...  -0.041357      -0.024087
# Final                        NaN  0.004446  ...   0.008765       0.019343
# Helicopters             0.490992 -0.061784  ...  -0.007880       0.066222
# Injuries                0.082642       NaN  ...   0.208648       0.036278
# Latitude                0.183643 -0.000472  ...  -0.078975      -0.011795
# Longitude              -0.036689 -0.041357  ...   1.000000      -0.027753
# MajorIncident                NaN -0.024087  ...  -0.027753       1.000000
# PercentContained             NaN       NaN  ...        NaN            NaN
# PersonnelInvolved       0.906887 -0.040159  ...   0.001122       0.086016
# Public                       NaN       NaN  ...        NaN            NaN
# StructuresDamaged       0.280688 -0.067474  ...  -0.114840       0.054116
# StructuresDestroyed     0.983604 -0.016154  ...  -0.049382       0.050924
# StructuresEvacuated          NaN       NaN  ...        NaN            NaN
# StructuresThreatened         NaN       NaN  ...  -0.150468            NaN
# WaterTenders           -0.377277 -0.074065  ...  -0.046212       0.077476
#
#                       PercentContained  PersonnelInvolved  Public  \
# AcresBurned                        NaN           0.258150     NaN
# Active                             NaN                NaN     NaN
# AirTankers                         NaN           0.434371     NaN
# ArchiveYear                        NaN          -0.040967     NaN
# CalFireIncident                    NaN          -0.029175     NaN
# CrewsInvolved                      NaN           0.823207     NaN
# Dozers                             NaN           0.753657     NaN
# Engines                            NaN           0.943634     NaN
# Fatalities                         NaN           0.906887     NaN
# Featured                           NaN          -0.040159     NaN
# Final                              NaN                NaN     NaN
# Helicopters                        NaN           0.574575     NaN
# Injuries                           NaN           0.575002     NaN
# Latitude                           NaN          -0.021810     NaN
# Longitude                          NaN           0.001122     NaN
# MajorIncident                      NaN           0.086016     NaN
# PercentContained                   NaN                NaN     NaN
# PersonnelInvolved                  NaN           1.000000     NaN
# Public                             NaN                NaN     NaN
# StructuresDamaged                  NaN          -0.015220     NaN
# StructuresDestroyed                NaN           0.096945     NaN
# StructuresEvacuated                NaN                NaN     NaN
# StructuresThreatened               NaN           0.704697     NaN
# WaterTenders                       NaN           0.816131     NaN
#
#                       StructuresDamaged  StructuresDestroyed  \
# AcresBurned                    0.380060             0.218043
# Active                              NaN                  NaN
# AirTankers                     0.887242             0.572404
# ArchiveYear                    0.139441             0.098759
# CalFireIncident                0.029366             0.033550
# CrewsInvolved                 -0.158452            -0.029503
# Dozers                         0.481004            -0.021198
# Engines                       -0.068927             0.066371
# Fatalities                     0.280688             0.983604
# Featured                      -0.067474            -0.016154
# Final                               NaN                  NaN
# Helicopters                   -0.354773            -0.105502
# Injuries                      -0.236605            -0.054871
# Latitude                       0.098044             0.060837
# Longitude                     -0.114840            -0.049382
# MajorIncident                  0.054116             0.050924
# PercentContained                    NaN                  NaN
# PersonnelInvolved             -0.015220             0.096945
# Public                              NaN                  NaN
# StructuresDamaged              1.000000             0.416163
# StructuresDestroyed            0.416163             1.000000
# StructuresEvacuated                 NaN                  NaN
# StructuresThreatened          -0.342261             0.466973
# WaterTenders                   0.278178            -0.028774
#
#                       StructuresEvacuated  StructuresThreatened  WaterTenders
# AcresBurned                           NaN              0.281418      0.359249
# Active                                NaN                   NaN           NaN
# AirTankers                            NaN             -0.076033      0.802913
# ArchiveYear                           NaN              0.086050     -0.031210
# CalFireIncident                       NaN              0.151947     -0.002747
# CrewsInvolved                         NaN              0.644368      0.736698
# Dozers                                NaN              0.593005      0.961062
# Engines                               NaN              0.634078      0.832994
# Fatalities                            NaN                   NaN     -0.377277
# Featured                              NaN                   NaN     -0.074065
# Final                                 NaN                   NaN           NaN
# Helicopters                           NaN              0.740237      0.699696
# Injuries                              NaN             -0.172003      0.241161
# Latitude                              NaN              0.233681      0.041513
# Longitude                             NaN             -0.150468     -0.046212
# MajorIncident                         NaN                   NaN      0.077476
# PercentContained                      NaN                   NaN           NaN
# PersonnelInvolved                     NaN              0.704697      0.816131
# Public                                NaN                   NaN           NaN
# StructuresDamaged                     NaN             -0.342261      0.278178
# StructuresDestroyed                   NaN              0.466973     -0.028774
# StructuresEvacuated                   NaN                   NaN           NaN
# StructuresThreatened                  NaN              1.000000      0.739554
# WaterTenders                          NaN              0.739554      1.000000
#
# [24 rows x 24 columns]
